# %% [markdown]
# ![人工智慧 - 自由團隊](https://raw.githubusercontent.com/chenkenanalytic/img/master/af/aifreeteam.png)
#
#
# <center>Welcome to the data deployment practice of Traditional Chinese Handwriting Dataset by AI . FREE Team.</center>
# <br>
# <center>歡迎大家來到 AI . FREE Team 所開發的繁體中文手寫資料部署實作範例。 </center>
# <br>
#
# <center>(Author: Chen Ken；Date of published: 2020/9/4；AI . FREE Team Website: https://aifreeblog.herokuapp.com/)</center>

# %%
# !git clone https://github.com/chenkenanalytic/handwritting_data_all.git
# Out:
# fatal: destination path 'handwritting_data_all' already exists and is not an empty directory.

# %%
# !cat 'D:\\handwritting_data_all-master\\all_data.zip'* > 'D:\\handwritting_data_all-master\\all_data.zip'
# Out:
# The system cannot find the path specified.

# %%
# !unzip -O big5 'D:\\handwritting_data_all-master\\all_data.zip' -d 'D:\\handwritting_data_all-master\\'
# Out:
# 'unzip' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import os
len(os.listdir('D:\\Traditional_Chinese_Data\\cleaned_data'))
a = 0
b = 0
def countfile(dir_path):
  global a
  global b
  for i in os.listdir(dir_path):
    full_path = dir_path + "/" + i
    if os.path.isfile(full_path):
      a+=1
    else:
      b+=1
      countfile(full_path)

countfile('D:\\Traditional_Chinese_Data\\cleaned_data')

print('總共: ' + str(b) + ' 個字(資料夾) / 總共: ' + str(a) + '個樣本')
print('平均每個字有: ' + str(a/b) + ' 個樣本')
# Out:
# 總共: 13065 個字(資料夾) / 總共: 684677個樣本
# 平均每個字有: 52.4054343666284 個樣本
